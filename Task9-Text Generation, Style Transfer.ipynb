# %% [markdown]
# # Text Generation, Style Transfer

# %% [markdown]
# ## Text Generation

# %%
import tensorflow.keras as keras
import tensorflow as tf
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path, 'r',-1, 'utf-8').read().lower()
print('corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 [==============================] - 1s 1us/step
# corpus length: 600893

# %%
# Length of extracted character sequences
maxlen = 60
# We sample a new sequence every `step` characters
step = 3
# This holds our extracted sequences
sentences = []
# This holds the targets (the follow-up characters)
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)
# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
from keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys
for epoch in range(1, 10):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)
    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 284s 180ms/step - loss: 1.9671
# --- Generating with seed: "amps, and pretend to be stars--the people
# then call them ide"
# ------ temperature: 0.2
# amps, and pretend to be stars--the people
# then call them ideally and in the stronger and from the stronger and to the something only the stronger and in the something in the stronger and in the stronger and the stronger and which the something is a more and present of the stronger of the from the stronger and stronger of the something in the desponsible of the stronger and stronger of the stronger of the stronger or the stronger of the something as a still
# ------ temperature: 0.5
#  of the stronger or the stronger of the something as a still man to he oreally and the more and more a stronger was the stronger and for the distrument estence and for the dust is a merild as former to de and all the freerly and the stronger of the from the sectrative in spilition of the stronger of the something as the interiorance. the more are the forto be stranger of the from the ralfing or to the regord only only and place on the spiritic in being als
# ------ temperature: 1.0
#  the regord only only and place on the spiritic in being alsuch, freverard" to commententard, aroum of agard put as an the spirit be refare a
# dbgin
# thriach oot to errry alwoild this oore,
# morele toze ortoress srist of mort only and
# proulter; kinds of himmelt. the restrangers of the
# som and remole to sachave from to emped arencenpelyming illf-to a piict" is the goed, the very formest or ode it percain, signay
# become
# or )ome frhirouse, which unrelownt overew
# ------ temperature: 1.2
# ain, signay
# become
# or )ome frhirouse, which unrelownt overewhord: in heajo
# clessns, must of questamessly afvoiving un-wricity.: bee herievent the primsiast: bodicals ho altvene
# the geanbasing" and givts tor
# and-lisefa"t
# doe stive, and own andifcoming ooinoung. becown buaw whict the
# preseramilud longerty, oo
# divinitamly of a
# peopesity firvn, erimanions of wally is, it that poait belobfin, this onitustly old comfutine conquest saskord--ank phesepostrasly (no
# epoch 2
# 1565/1565 [==============================] - 281s 179ms/step - loss: 1.6135
# --- Generating with seed: "ntinue, it can
# only do so as a form of luxury, as an archaiz"
# ------ temperature: 0.2
# ntinue, it can
# only do so as a form of luxury, as an archaized the consequently the manifes and sense of the many the conceal oftrunt of the conceal of the most remains and the manifes and as the sense of the present and literally the sense and the sense of the sense of the conceal one as sense of the conceance of the manifes in the conceal oftrunce of the conceal one as a man to the conceal of the more the manifes of the mance of the most one more manner
# ------ temperature: 0.5
# e more the manifes of the mance of the most one more manner and men and new a the phere all a contreating in the deed that the christian reason cannot as a destance, which is the the content and who christian which every manness of the many mankers as the selfing and intentions the me many intelling outborated the will
# only when the strength of sacrifice of the problem of the contemnt of all this probles the were will it has here became place and present t
# ------ temperature: 1.0
# probles the were will it has here became place and present this nature opething ofts-pals of whhe grow how such eefuls will herouglet not it a bothoral
# unmwilar all a misdinggious  concealing as the
# moral quired outten ant difference of the terposs
# patuebups he sapides of sense, everyen is the sund-things--belong,
#
# not hmanished first herefathers may to antimated who give or
# and soul--ancal's tweance the ent
# places "as a greated dimble involunt. being over
# ------ temperature: 1.2
# nce the ent
# places "as a greated dimble involunt. being over creater intallhy now the wild, oncaristing, ar them: itsileg
# alesw he will most
# valuwate it sools and now prouded mankard.cirishs
# "present new "moseming, phrinarity
# it up, it we elixtaish is could ver that that paration has wener it of sa.by concluse milipests: an obloned from will as gives always a mate the uptile graterminices, why "iudle, (the custamsy prove verstmontariw orcald oft, eobidain
# epoch 3
# 1565/1565 [==============================] - 278s 178ms/step - loss: 1.5268
# --- Generating with seed: "he is troubled about the health,
# or the pettiness and confin"
# ------ temperature: 0.2
# he is troubled about the health,
# or the pettiness and confiners of the sense of the stroke and such and the distinguses of the profound and and and and individual and and have a profound and and such as a substingty and and in the same and the stroke the destraint of the profound and the conscience of the every profound and and the stroke and the stroke and all the stroke the stroke and and and all the profound and and the sense of the stroke and and as th
# ------ temperature: 0.5
# l the profound and and the sense of the stroke and and as the fact the how to the of the man good the acts of the seast of a ment of all the taste of the part and and in all whole of the principle, and and the greatest the soul, the stroke and individual whole restings and the soried whole wholl and the conscient offent of philosophy of the marking and himself, and individual and conceptions and scion--whold his soliture and in our only of the cause how co
# ------ temperature: 1.0
# cion--whold his soliture and in our only of the cause how consequence, is
# also have to" thenoat. when "eme.--f his raight of
# allight, as grattions and pains, which                     he do besuslest only here
# distrip only whereother old conurest higher that hen provar towerly: what
# so
# sa. rangs which our itself.--of have the sny,g
# and and allifuls,
# indefiner overthietine that wa thinks, something spiritual posses.. the armother suffer, seffiply and cure i
# ------ temperature: 1.2
#  spiritual posses.. the armother suffer, seffiply and cure inster-alless of act: no thing european. morrough also ohe kniwall handedncul, pessions and
# to, happings sparciin there
# as tramitisasly- strofces-swe shy, to delelting; instily,gment bavent haves-pest of this
# gerings for which and suppier, caker mo:--who
# have its abvol. they hoo occe time rights, which
# madilied
# tuty hibre. the everye
# only forwy ethiclus naturt hare,
# which enting memores, as can bo
#
# epoch 4
# 1565/1565 [==============================] - 283s 181ms/step - loss: 1.4819
# --- Generating with seed: "f learning brought
# with it, we may begin to bear still farth"
# ------ temperature: 0.2
# f learning brought
# with it, we may begin to bear still farther and and as a such an antimate the same that it is the same that the same to be such an alle the souls the same the same the same to the same to the same to the same to an antimate the superficiance, and the simploness of the same the present the same to the same to the superficial into the same the superficial and and the sense that the present the self-such a such a such an antimate the presen
# ------ temperature: 0.5
# e present the self-such a such a such an antimate the present in the same the instance and interrend turn man, and the faction to its organical that the superficial and and
# as its truth prevailing and whatever a strulthers of the problem of the will be eternality of the way to that is the deal of the religion of the man in flesting of mentan in the present
# into the merely the same thinkers has instance, the
# sensition and no present and will in the heart of
# ------ temperature: 1.0
# tance, the
# sensition and no present and will in the heart of seemgny, something perhaps, that the prigat; to else. which rasmeroned
# and patimself, and onen, andnened
# strainy not to to for the the moral arrow rute. these more
# further and tragedy to open a
# whate; is through prostingthing an a!s owing of that the orignas
# will
# nothing feelings!
#
# . and supretation, this a great in these seemkeratones
# lawnisce: one of the subtle, to instance, us
# was too
# lofihism
# ------ temperature: 1.2
# awnisce: one of the subtle, to instance, us
# was too
# lofihism that was than a chereve offenfidicumines thys; are natureacye period by so ot. for dein
# filmesm of
# says. the sublite pehnesses has fari1rapious was
# and going to good, the scarns; from of
# the priath: with uponly manicthareated, has
# just-araoned he wable effected
# orages that i sider, grasp, sinfinationce, fact.--but wone mp eler take. pits ravicary and its inited those life in this literat, extend
# epoch 5
# 1565/1565 [==============================] - 281s 179ms/step - loss: 1.4508
# --- Generating with seed: "limbs are
# benumbed and his spirits are now too heavy! "it is"
# ------ temperature: 0.2
# limbs are
# benumbed and his spirits are now too heavy! "it is not the sense of the properse of the opinion of the same to the sense of the same the sense of the souls and the souls and the most man as the world and and say and the souls and the sense of the sense of the self-consideration of the most consequently to the souls the souls to the sentiments, and consequently and the same the same things of the same conscious to the world of the same the most so
# ------ temperature: 0.5
# s of the same conscious to the world of the same the most souther the post the all the rank-all in the far the properience speak, the intermoral willing and expression of the inclent and signisism of the man and resists and disconsibility, the schoic only such every sciences that the sentiment--there is a in the most to be in the same the conscious of the end to regardes patter and their no a surper in the same the decidence of the most the in the cirely i
# ------ temperature: 1.0
# er in the same the decidence of the most the in the cirely indeed
# thren end exucinieloned of temptibuially in perrandness of darring of the incarmonal nigent dutience--there is now the brought, and to tnetion,
# interrenction of the scco-dury into point immon profomle, the jesses--invedition somethings that verit for society of
# tle times of the joses upon the opsyptized another placed. something minfular, arone of now
# own, that who the itse
# him thereopiwer e
# ------ temperature: 1.2
# fular, arone of now
# own, that who the itse
# him thereopiwer entise effected, the new rual regardenicary well enougher obje which, his stride ot-veinge sames that recape of smick", fut inso eprokilijes
# as
# thems,
# that persmin peinoning ever say it phate of living innocent. , its usowiness, a pregrerred a hostiel fellom as
# sleep to enchive a
# sourrow a knod fore: )he assignds means of sotumique iseok proret of lookeds will not whoever, apsecrs their time is pro
# epoch 6
# 1565/1565 [==============================] - 281s 180ms/step - loss: 1.4299
# --- Generating with seed: "circumnavigators and
# adventurers of that inner world called "
# ------ temperature: 0.2
# circumnavigators and
# adventurers of that inner world called and and and the proversoped the antich the distrust and an account the conduct and the world and who has a stronger of the same the and and also the strength of the proversion to the soul of the most conduct that the strength of the religion of the strength and the religion of the strength of the conduct is the anticher and and allowed be sochesing the most supering and the strength of the strengt
# ------ temperature: 0.5
#  sochesing the most supering and the strength of the strength and more and the cruelty of men and allowed desire more reason of the dangerous things should the history of the belief more things, and love condemed to the delight of the proversions of a variety the proves and the more and a fair the deating man of the world because and in the sake, the
# there are allow--in the way in which the hist only to the worthical does not the proversands to a supressin
# ------ temperature: 1.0
# nly to the worthical does not the proversands to a supressing
# and herise most justices and you. but restrain except in.= tenders for theyvely, hour "indication of a conscient condrence of the experience, his master--in the cron german sole
# party and it has it -alonger vairists and in advantation, micklow. ffer the know hi,
# ur and had to man, proves as he utity than theures, we light; for an almosen, deating, and duet extration of agand to be allowed has
# un
# ------ temperature: 1.2
# n, deating, and duet extration of agand to be allowed has
# undever, and cupiltus nature. this bangulous, class of worthing hexpliculate buildculs or woman
# worthap of unnow laty from
# shelloighth.
#
#
# neit lie
# troracan sign humlies: one say have taken dos thosan, those moraliages
# which, but
# tortay occasiously.
#
# en alsover, the futuatiuns: he card: in all
# otwered extent of higherness
# of to
# animatedness. but he are foves though which xhere underbinales withdout.
# epoch 7
# 1565/1565 [==============================] - 284s 182ms/step - loss: 1.4137
# --- Generating with seed: " opinion, and afterwards
# to believe implicitly in this opini"
# ------ temperature: 0.2
#  opinion, and afterwards
# to believe implicitly in this opinion of the present the faith the spirit of the fact of the sentiment and a surply the species of the predicated to the predicated the power that the predides and predicated the same are the sensition of the present the same are the same that it is the same that it is a soul of the predicate a have the contrainished to the present the present the strength of the conception of the predicated to be th
# ------ temperature: 0.5
# nt the strength of the conception of the predicated to be the reason and self-all the propert of this prediten the most thing so entionel has a senture to the always been found man and complexive and fainatise
# in the strength of the greek, who have for the perhaps in the thring so the presence of the discontury of his suspect former that the backgy that it principal and more former all so that the former of the same in the same and surplament and would imp
# ------ temperature: 1.0
#  former of the same in the same and surplament and would impends not so vround
# man contarien. at gines tove made iborius.
#
# 14o, four lically death univent the profort its
# meaneness--in the more too, to himself the digullation than theke the contlul hied right and
# caken that overmer, and imagen: is ito
# potering truthhmenth advant things.--the humant higher, the europefo and vinder.
# thue german
# must strife--through dictateneran are a facrual too prover conte
# ------ temperature: 1.2
#  strife--through dictateneran are a facrual too prover contequine for the judg, education shorequentously it not as slamenis? a concrave of vaneution in gene(tuner? thinkest rater to
# be mean must., soturgencetin. no ided same was
# contraited tomacped
# to yel distinction of aally regardens, or she though all danturing
# and the more frarge,--a reduly it "sachicial haid due arochinane x ! wherly
# the willing man takes:
# never yous evil what has every: in the
# papoc
# epoch 8
# 1565/1565 [==============================] - 286s 183ms/step - loss: 1.3987
# --- Generating with seed: "of his tolerance, in the
# unsuspecting, simple certainty with"
# ------ temperature: 0.2
# of his tolerance, in the
# unsuspecting, simple certainty with the states of the existing to the states and the states and the science of the subject and that the states and the states of the states of the states and the states of the strength of the religion of the states and some the man is always that the soul, and in the states and the souls that the states and sange his faring of the states of the souls that the stronger in the states of the states and
# ------ temperature: 0.5
# the souls that the stronger in the states of the states and the states of the states and state of the still his parenism for the believe the freedom of the higher is as a great that the way of the conceitary proper disposine, something has always some the factly and nothing when he say there as feels of the world would have one say of the fact in the same and not one the way of the spirit in the pareness, who say no longer because all possible man in sense
# ------ temperature: 1.0
# areness, who say no longer because all possible man in sense its, but because of submit
# do the coarses, preacressity
# are istrancentamiantaristicy, a science it possible a one is sould,
# deconnocening siminch, or all the decoled of
# the so ranfupally ception case of "commandsity and peoples with the can still the medi, in view an
# action of his nowadays;--that an all fliscing quinication to decassuales, he one who conditions manning that has quest with even se
# ------ temperature: 1.2
# s, he one who conditions manning that has quest with even seventa
# itery thing he has knowledgeful notehs, the sympathines) afthing higher tanoye adapte stenshood charatal far in boond, humble of the way, its
# festile feel i apwhild who makem to finding
# that cuprance, orckepars equals there even
# cprope moral farulatilive, he likewisess form far zon parens, possesing ranle not
# always tooded pare--bren"y-gadher darmon
# them conceirement
# a jwarm the one fo red
# b
# epoch 9
# 1565/1565 [==============================] - 283s 181ms/step - loss: 1.3875
# --- Generating with seed: "ting still; and how many
# a one, just as he "sprang up," has "
# ------ temperature: 0.2
# ting still; and how many
# a one, just as he "sprang up," has different the same the sense of the same the best the moral presented for the same of the same the present more suffered to be a man the sense of the same and as the case, and the most really and the present more free spirit the sense of the same the moral conduct of the same and the same of the sense of the conduct some the state of the same the sense of the same and the conduct to the same indif
# ------ temperature: 0.5
# same the sense of the same and the conduct to the same indifficult as into the art that the serious are the world of the very play and as it be appearance of the most decised and present and condition of the rests and being the origin, and not to the same and for the pression
# of the delicate of self-respect to an artists and slave, it not possible impossible and faith the belief, he has always be the german and weaking has
# delight and indealctive and indif
# ------ temperature: 1.0
# the german and weaking has
# delight and indealctive and indifferent for "look, to all bventently amact you them for teasatidiousness,
# also and have believe foolsions had not destonatly a fate, name of danger, there frewdould not
# to that
# when i feels timement: by the orcations, affect, to lest respons it orliartl wait ghast them and imploousk of a just,
# praise for europe, additations, "menscofund,"
# counce iving agame,. we ares when every summuss", some must
# ------ temperature: 1.2
# counce iving agame,. we ares when every summuss", some must althis
# fact imprestion,
# matter over h
# telo-a-dresse trulisitus
# of no
# venenary,
# because institementages of the most and fath, and
# toule proved so
# sum; allity.
#
#               ulority." and ears of
# cevt anday are expesitus). penest of the most scientificalitary and have,
# deli
# obts the requires undersin,
# misundiented lab"-absir if dager, firsow-d""ging experated
# problem of untrustk pehilises dopurtal

# %% [markdown]
# ## Style transfer

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import IPython.display as display

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (12,12)
mpl.rcParams['axes.grid'] = False

import numpy as np
import time
import functools

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
content_path= '/content/drive/MyDrive/Dataset/style_transfer/cat.jpg'
style_path='/content/drive/MyDrive/Dataset/style_transfer/starry_night.jpg'
# Out:
# Mounted at /content/drive

# %%
def load_img(path_to_img):
    max_dim = 512
    img = tf.io.read_file(path_to_img)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)

    shape = tf.cast(tf.shape(img)[:-1], tf.float32)
    long_dim = max(shape)
    scale = max_dim / long_dim

    new_shape = tf.cast(shape * scale, tf.int32)

    img = tf.image.resize(img, new_shape)
    img = img[tf.newaxis, :]
    return img

# %%
def imshow(image, title=None):
    if len(image.shape) > 3:
        image = tf.squeeze(image, axis=0)

    plt.imshow(image)
    if title:
        plt.title(title)

# %%
content_image = load_img(content_path)
style_image = load_img(style_path)

plt.subplot(1, 2, 1)
imshow(content_image, 'Content Image') # 이 이미지에

plt.subplot(1, 2, 2)
imshow(style_image, 'Style Image') # 이 스타일을 입혀보자!

# %% [markdown]
# Build a pretrained VGG model with Imagenet

# %%
x = tf.keras.applications.vgg19.preprocess_input(content_image*255)
x = tf.image.resize(x, (224, 224))
vgg = tf.keras.applications.VGG19(include_top=True, weights='imagenet')
r = vgg(x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574710816/574710816 [==============================] - 10s 0us/step

# %%
labels_path = tf.keras.utils.get_file(
    'ImageNetLabels.txt', 'https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
imagenet_labels = np.array(open(labels_path).read().splitlines())

print(imagenet_labels[np.argsort(r)[0,::-1][:5]+1])
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt
# 10484/10484 [==============================] - 0s 0us/step
# ['tabby' 'Egyptian cat' 'tiger cat' 'Norwich terrier' 'piggy bank']

# %%
vgg = tf.keras.applications.VGG19(include_top=False, weights='imagenet')

print()
for layer in vgg.layers:
  print(layer.name)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step
#
# input_2
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_conv4
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_conv4
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_conv4
# block5_pool

# %%
# Content layer where will pull our feature maps
content_layers = ['block5_conv2'] 

# Style layer we are interested in
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1', 
                'block4_conv1', 
                'block5_conv1']

num_content_layers = len(content_layers)
num_style_layers = len(style_layers)

# %%
def vgg_layers(layer_names):
  # Creates a vgg model that returns a list of intermediate output values.
  # Load our model. We load pretrained VGG, trained on imagenet data
    vgg = tf.keras.applications.VGG19(include_top=False, weights='imagenet')
    vgg.trainable = False
  
    outputs = [vgg.get_layer(name).output for name in layer_names]

    model = tf.keras.Model([vgg.input], outputs)
    return model

# %%
style_extractor = vgg_layers(style_layers)
style_outputs = style_extractor(style_image*255)

#Look at the statistics of each layer's output
for name, output in zip(style_layers, style_outputs):
    print(name)
    print("  shape: ", output.numpy().shape)
    print("  min: ", output.numpy().min())
    print("  max: ", output.numpy().max())
    print("  mean: ", output.numpy().mean())
    print()
# Out:
# block1_conv1
#   shape:  (1, 406, 512, 64)
#   min:  0.0
#   max:  707.1314
#   mean:  21.92893
#
# block2_conv1
#   shape:  (1, 203, 256, 128)
#   min:  0.0
#   max:  2439.1912
#   mean:  129.38834
#
# block3_conv1
#   shape:  (1, 101, 128, 256)
#   min:  0.0
#   max:  7562.7827
#   mean:  122.63791
#
# block4_conv1
#   shape:  (1, 50, 64, 512)
#   min:  0.0
#   max:  16078.676
#   mean:  490.2341
#
# block5_conv1
#   shape:  (1, 25, 32, 512)
#   min:  0.0
#   max:  3324.067
#   mean:  41.042652

# %%
def gram_matrix(input_tensor):
    result = tf.linalg.einsum('bijc,bijd->bcd', input_tensor, input_tensor)
    input_shape = tf.shape(input_tensor)
    num_locations = tf.cast(input_shape[1]*input_shape[2], tf.float32)
    return result/(num_locations)

# %%
class StyleContentModel(tf.keras.models.Model):
    def __init__(self, style_layers, content_layers):
        super(StyleContentModel, self).__init__()
        self.vgg =  vgg_layers(style_layers + content_layers)
        self.style_layers = style_layers
        self.content_layers = content_layers
        self.num_style_layers = len(style_layers)
        self.vgg.trainable = False

    def call(self, inputs):
        inputs = inputs*255.0
        preprocessed_input = tf.keras.applications.vgg19.preprocess_input(inputs)
        outputs = self.vgg(preprocessed_input)
        style_outputs, content_outputs = (outputs[:self.num_style_layers], 
                                          outputs[self.num_style_layers:])

        style_outputs = [gram_matrix(style_output)
                         for style_output in style_outputs]

        content_dict = {content_name:value 
                        for content_name, value 
                        in zip(self.content_layers, content_outputs)}

        style_dict = {style_name:value
                      for style_name, value
                      in zip(self.style_layers, style_outputs)}

        return {'content':content_dict, 'style':style_dict}

# %%
extractor = StyleContentModel(style_layers, content_layers)

results = extractor(tf.constant(content_image))

style_results = results['style']

print('Styles:')
for name, output in sorted(results['style'].items()):
    print("  ", name)
    print("    shape: ", output.numpy().shape)
    print("    min: ", output.numpy().min())
    print("    max: ", output.numpy().max())
    print("    mean: ", output.numpy().mean())
    print()

print("Contents:")
for name, output in sorted(results['content'].items()):
    print("  ", name)
    print("    shape: ", output.numpy().shape)
    print("    min: ", output.numpy().min())
    print("    max: ", output.numpy().max())
    print("    mean: ", output.numpy().mean())
# Out:
# Styles:
#    block1_conv1
#     shape:  (1, 64, 64)
#     min:  0.0
#     max:  168992.12
#     mean:  413.55838
#
#    block2_conv1
#     shape:  (1, 128, 128)
#     min:  0.0
#     max:  279494.5
#     mean:  10322.939
#
#    block3_conv1
#     shape:  (1, 256, 256)
#     min:  0.0
#     max:  381146.75
#     mean:  7336.9937
#
#    block4_conv1
#     shape:  (1, 512, 512)
#     min:  0.0
#     max:  4177247.2
#     mean:  103381.09
#
#    block5_conv1
#     shape:  (1, 512, 512)
#     min:  0.0
#     max:  47497.023
#     mean:  606.8485
#
# Contents:
#    block5_conv2
#     shape:  (1, 32, 32, 512)
#     min:  0.0
#     max:  1156.6023
#     mean:  7.315929

# %% [markdown]
# Training

# %%
style_targets = extractor(style_image)['style']
content_targets = extractor(content_image)['content']
image = tf.Variable(content_image)

# %%
def clip_0_1(image):
    return tf.clip_by_value(image, clip_value_min=0.0, clip_value_max=1.0)

# %%
def style_content_loss(outputs):
    style_outputs = outputs['style']
    content_outputs = outputs['content']
    style_loss = tf.add_n([tf.reduce_mean((style_outputs[name]-style_targets[name])**2)
                        for name in style_outputs.keys()])
    
    style_loss *= style_weight / num_style_layers
    
    content_loss = tf.add_n([tf.reduce_mean((content_outputs[name]-content_targets[name])**2)
                        for name in content_outputs.keys()])
    
    content_loss *= content_weight / num_content_layers
    loss = style_loss + content_loss
    return loss

# %%
opt = tf.optimizers.Adam(learning_rate=0.02, beta_1=0.99, epsilon=1e-1)
style_weight = 1e-2
content_weight = 1e4

# %%
@tf.function()
def train_step(image):
    with tf.GradientTape() as tape:
        outputs = extractor(image)
        loss = style_content_loss(outputs)

        grad = tape.gradient(loss, image)
        opt.apply_gradients([(grad, image)])
        image.assign(clip_0_1(image))

# %%
train_step(image)
train_step(image)
train_step(image)
plt.imshow(image.read_value()[0])

# %% [markdown]
# Training (Additional)

# %%
epochs = 10
steps_per_epoch = 10

step = 0
for n in range(epochs):
    for m in range(steps_per_epoch):
        step += 1
        train_step(image)
    display.clear_output(wait=True)
    imshow(image.read_value())
    plt.title("Train step: {}".format(step))
    plt.show()
